# %%
import condb as con
# data = con.selectData(table="users")
# print(data[1][6])
# for i in data:
#     print(i)

# %%
data = con.selectData(table="fuel")
for i in data:
    print(i)
# Out:
# (0, 'Petrol')
# (1, 'Diesel')
# (2, 'Hybrid')
# (3, 'Electric')
# (4, 'Other')

# %%
con.insertData(table="product_type", primary_key="'T05'", values="'หมาดำ', 'หมาหมา'")
# Out:
# 1 row inserted
# True

# %%
con.updateData(table="product_type", set="tname='หมาแดง'", condition="tid='T02'")
# Out:
# 1 row updated
# True

# %%
con.deleteData(table="product_type", condition="tid='T01'")
# Out:
# 1 row deleted
# True

# %%
a = "t"
b = "None"

if a and b:
    print("here")
# Out:
# here

# %%
# Import pandas
import pandas as pd

# reading csv file 
df = pd.read_csv(r'D:\KKU_World\1_2\DBMS\termProject\python\Ai\dataset\archive\ford.csv')
df
# Out:
#         model  year  price transmission  mileage fuelType  tax   mpg  \
# 0      Fiesta  2017  12000    Automatic    15944   Petrol  150  57.7
# 1       Focus  2018  14000       Manual     9083   Petrol  150  57.7
# 2       Focus  2017  13000       Manual    12456   Petrol  150  57.7
# 3      Fiesta  2019  17500       Manual    10460   Petrol  145  40.3
# 4      Fiesta  2019  16500    Automatic     1482   Petrol  145  48.7
# ...       ...   ...    ...          ...      ...      ...  ...   ...
# 17961   B-MAX  2017   8999       Manual    16700   Petrol  150  47.1
# 17962   B-MAX  2014   7499       Manual    40700   Petrol   30  57.7
# 17963   Focus  2015   9999       Manual     7010   Diesel   20  67.3
# 17964      KA  2018   8299       Manual     5007   Petrol  145  57.7
# 17965   Focus  2015   8299       Manual     5007   Petrol   22  57.7
#
#        engineSize
# 0             1.0
# 1             1.0
# 2             1.0
# 3             1.5
# 4             1.0
# ...           ...
# ...

# %%
data = df.drop(['price', 'tax'], axis=1)
data
# Out:
#         model  year transmission  mileage fuelType   mpg  engineSize
# 0      Fiesta  2017    Automatic    15944   Petrol  57.7         1.0
# 1       Focus  2018       Manual     9083   Petrol  57.7         1.0
# 2       Focus  2017       Manual    12456   Petrol  57.7         1.0
# 3      Fiesta  2019       Manual    10460   Petrol  40.3         1.5
# 4      Fiesta  2019    Automatic     1482   Petrol  48.7         1.0
# ...       ...   ...          ...      ...      ...   ...         ...
# 17961   B-MAX  2017       Manual    16700   Petrol  47.1         1.4
# 17962   B-MAX  2014       Manual    40700   Petrol  57.7         1.0
# 17963   Focus  2015       Manual     7010   Diesel  67.3         1.6
# 17964      KA  2018       Manual     5007   Petrol  57.7         1.2
# 17965   Focus  2015       Manual     5007   Petrol  57.7         1.0
#
# [17966 rows x 7 columns]

# %%
model_mapping = {
    'Fiesta': 0,
    'Focus': 1,
    'Kuga': 2,
    'EcoSport': 3,
    'C-MAX': 4,
    'Ka+': 5,
    'Mondeo': 6,
    'B-MAX': 7,
    'S-MAX': 8,
    'Grand C-MAX': 9,
    'Galaxy': 10,
    'Edge': 11,
    'KA': 12,
    'Puma': 13,
    'Tourneo Custom': 14,
    'Grand Tourneo Connect': 15,
    'Mustang': 16,
    'Tourneo Connect': 17,
    'Fusion': 18,
    'Streetka': 19,
    'Ranger': 20,
    'Escort': 21,
    'Transit Tourneo': 22
}

transmission_mapping = {
    'Manual': 0,
    'Automatic': 1,
    'Semi-Auto': 2
}

fuel_mapping = {
    'Petrol': 0,
    'Diesel': 1,
    'Hybrid': 2,
    'Electric': 3,
    'Other': 4
}

# %%
exist_data = []
j = 0
for i in range(len(data['model'])):
    format_data = [data['model'][i], data['year'][i], data['engineSize'][i], data['mpg'][i], transmission_mapping[data['transmission'][i]], fuel_mapping[data['fuelType'][i]]]
    if format_data not in exist_data:
        exist_data.append(format_data)
        con.insertData(table='car', primary_key=j, values=f"'{format_data[0]}', '{format_data[1]}', '{format_data[2]}', '{format_data[3]}', '{format_data[4]}', '{format_data[5]}'")
        j+=1
# Out:
# 1 row inserted
# 1 row inserted
# 1 row inserted
# 1 row inserted
# 1 row inserted
# 1 row inserted
# 1 row inserted
# 1 row inserted
# 1 row inserted
# 1 row inserted
# 1 row inserted
# 1 row inserted
# 1 row inserted
# 1 row inserted
# 1 row inserted
# 1 row inserted
# 1 row inserted
# 1 row inserted
# 1 row inserted
# 1 row inserted
# 1 row inserted
# 1 row inserted
# 1 row inserted
# 1 row inserted
# 1 row inserted
# 1 row inserted
# 1 row inserted
# 1 row inserted
# 1 row inserted
# 1 row inserted
# 1 row inserted
# 1 row inserted
# 1 row inserted
# 1 row inserted
# 1 row inserted
# 1 row inserted
# 1 row inserted
# 1 row inserted
# 1 row inserted
# 1 row inserted
# 1 row inserted
# 1 row inserted
# 1 row inserted
# 1 row inserted
# 1 row inserted
# 1 row inserted
# 1 row inserted
# 1 row inserted
# 1 row inserted
# 1 row inserted
# 1 row inserted
# 1 row inserted
# 1 row inserted
# 1 row inserted
# 1 row inserted
# 1 row inserted
# 1 row inserted
# 1 row inserted
# ...

# %%
con.deleteData(table='car', condition="1=1")
# Out:
# 0 row deleted
# True
